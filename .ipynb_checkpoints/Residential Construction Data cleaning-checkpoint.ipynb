# %%
import pandas as pd

# %% [markdown]
# # Reason for using this data

# %% [markdown]
# This documentation was chosen due to the accuracy of the information. Every local government, and on the East coast private issuers of permits, provides statistical information each month to the government. They have been doing this since 1970. even though there is a possibility of errors, they will be minor considering the amount of information gathered and the prolonged period of time this has been happening.
#
# The files have been downloaded per State with the information from 1970. The files have then been adjusted to show the information relevant to answer our question of impact of Covid 19 on the industry.

# %% [markdown]
# # Loading all files into the workbook

# %% [markdown]
# All files show the top of the table to make sure all the information is the same and accounted for.
#
# All data relates to residential building work separated int he following types:
# - Dwellings
# - Townhouses: Semi-detached, row, terrace and townhouses all single and multi storey buildings
# - Apartments: Flats, units and apartments all single and multi storey buildings
# - Other: Additions and alterations

# %% [markdown]
# ## ACT

# %%
ACT_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, ACT.csv')
ACT_df.head()
ACT_df
# Out:
#            Unnamed: 0  \
# 0                Unit
# 1         Series Type
# 2           Data Type
# 3           Frequency
# 4    Collection Month
# ..                ...
# 672          Apr-2020
# 673          May-2020
# 674          Jun-2020
# 675          Jul-2020
# 676          Aug-2020
#
#     Total number of dwelling units ;  Australian Capital Territory ;  New ;  Houses ;  \
# 0                                               Number
# 1                                             Original
# 2                                                 FLOW
# 3                                                Month
# 4                                                    1
# ..                                                 ...
# 672                                                 95
# 673                                                122
# 674                                                 90
# 675                                                109
# ...

# %%
ACT_df = ACT_df.iloc[654:675, :]
ACT_df = ACT_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
ACT_df
# Out:
#     Unnamed: 0  \
# 654   Oct-2018
# 655   Nov-2018
# 656   Dec-2018
# 657   Jan-2019
# 658   Feb-2019
# 659   Mar-2019
# 660   Apr-2019
# 661   May-2019
# 662   Jun-2019
# 663   Jul-2019
# 664   Aug-2019
# 665   Sep-2019
# 666   Oct-2019
# 667   Nov-2019
# 668   Dec-2019
# 669   Jan-2020
# 670   Feb-2020
# 671   Mar-2020
# 672   Apr-2020
# 673   May-2020
# 674   Jun-2020
#
#     Total number of dwelling units ;  Australian Capital Territory ;  New ;  Houses ;  \
# 654                                                133
# 655                                                123
# 656                                                 75
# 657                                                 75
# 658                                                119
# 659                                                106
# 660                                                 69
# 661                                                 81
# 662                                                 95
# ...

# %%
ACT_df = ACT_df.rename(columns={
    'Unnamed: 0': '',
    'Total number of dwelling units ;  Australian Capital Territory ;  New ;  Houses ;': 'ACT_dwellings',
    'Total number of dwelling units ;  Australian Capital Territory ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': 'ACT_townhouses',
    'Total number of dwelling units ;  Australian Capital Territory ;  New ;  Flats units or apartments - Total including those attached to a house ;': 'ACT_apartments',
    'Total number of dwelling units ;  Australian Capital Territory ;  New ;  Total Other Residential ;': 'ACT_other',
    'Total value of building jobs ;  Australian Capital Territory ;  New ;  Houses ;': "ACT_dwellings_$'000",
    'Total value of building jobs ;  Australian Capital Territory ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "ACT_townhouses_$'000",
    'Total value of building jobs ;  Australian Capital Territory ;  New ;  Flats units or apartments - Total including those attached to a house ;': "ACT_apartments_$'000",
    'Total value of building jobs ;  Australian Capital Territory ;  New ;  Total Other Residential ;': "ACT_other_$'000"})
ACT_df = ACT_df.set_index('')
ACT_df
# Out:
#          ACT_dwellings ACT_townhouses ACT_apartments ACT_other  \
#
# Oct-2018           133             80            439       519
# Nov-2018           123             90            349       439
# Dec-2018            75             98             85       183
# Jan-2019            75            133             94       227
# Feb-2019           119            140              0       140
# Mar-2019           106             25            430       455
# Apr-2019            69            196            413       609
# May-2019            81            107              0       107
# Jun-2019            95            100             43       143
# Jul-2019            92             74              0        74
# Aug-2019           109            120             19       139
# Sep-2019           116             31            835       866
# Oct-2019           116             67             29        96
# Nov-2019           120             29             59        88
# ...

# %%
ACT_df = ACT_df.T
ACT_df
# Out:
#                      Oct-2018 Nov-2018 Dec-2018 Jan-2019 Feb-2019 Mar-2019  \
# ACT_dwellings             133      123       75       75      119      106
# ACT_townhouses             80       90       98      133      140       25
# ACT_apartments            439      349       85       94        0      430
# ACT_other                 519      439      183      227      140      455
# ACT_dwellings_$'000     51156    45194    26703    33687    44973    41343
# ACT_townhouses_$'000    21558    24164    23614    31522    34193     7149
# ACT_apartments_$'000   116989   128910    31874    16200        0   180000
# ACT_other_$'000        138547   153074    55488    47722    34193   187149
#
#                      Apr-2019 May-2019 Jun-2019 Jul-2019  ... Sep-2019  \
# ACT_dwellings              69       81       95       92  ...      116
# ACT_townhouses            196      107      100       74  ...       31
# ACT_apartments            413        0       43        0  ...      835
# ...

# %% [markdown]
# ## NSW

# %%
NSW_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, NSW.csv')
NSW_df.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Total number of dwelling units ;  New South Wales ;  New ;  Houses ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
#   Total number of dwelling units ;  New South Wales ;  New ;  Semi-detached, row or terrace houses, townhouses - One storey ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
# ...

# %%
NSW_df = NSW_df.iloc[654:675, :]
NSW_df = NSW_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
NSW_df
# Out:
#     Unnamed: 0  \
# 654   Oct-2018
# 655   Nov-2018
# 656   Dec-2018
# 657   Jan-2019
# 658   Feb-2019
# 659   Mar-2019
# 660   Apr-2019
# 661   May-2019
# 662   Jun-2019
# 663   Jul-2019
# 664   Aug-2019
# 665   Sep-2019
# 666   Oct-2019
# 667   Nov-2019
# 668   Dec-2019
# 669   Jan-2020
# 670   Feb-2020
# 671   Mar-2020
# 672   Apr-2020
# 673   May-2020
# 674   Jun-2020
#
#     Total number of dwelling units ;  New South Wales ;  New ;  Houses ;  \
# 654                                               2729
# 655                                               2600
# 656                                               1971
# 657                                               1980
# 658                                               2046
# 659                                               2201
# 660                                               1746
# 661                                               2365
# 662                                               2000
# ...

# %%
NSW_df = NSW_df.rename(columns={'Unnamed: 0': "",
       'Total number of dwelling units ;  New South Wales ;  New ;  Houses ;': "NSW_dwellings",
       'Total number of dwelling units ;  New South Wales ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "NSW_townhouses",
       'Total number of dwelling units ;  New South Wales ;  New ;  Flats units or apartments - Total including those attached to a house ;': "NSW_apartments",
       'Total number of dwelling units ;  New South Wales ;  New ;  Total Other Residential ;': "NSW_other",
       'Total value of building jobs ;  New South Wales ;  New ;  Houses ;': "NSW_dwellings_$'000",
       'Total value of building jobs ;  New South Wales ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "NSW_townhouses_$'000",
       'Total value of building jobs ;  New South Wales ;  New ;  Flats units or apartments - Total including those attached to a house ;': "NSW_apartments_$'000",
       'Total value of building jobs ;  New South Wales ;  New ;  Total Other Residential ;': "NSW_other_$'000"})
NSW_df = NSW_df.set_index('')
NSW_df
# Out:
#          NSW_dwellings NSW_townhouses NSW_apartments NSW_other  \
#
# Oct-2018          2729            669           2179      2848
# Nov-2018          2600            834           1217      2051
# Dec-2018          1971            519           1461      1980
# Jan-2019          1980            642           1254      1896
# Feb-2019          2046            749           2296      3045
# Mar-2019          2201            788           1337      2125
# Apr-2019          1746            599           1801      2400
# May-2019          2365            728           1800      2528
# Jun-2019          2000            596           1477      2073
# Jul-2019          2589            607            932      1539
# Aug-2019          2076            670           1445      2115
# Sep-2019          1991            774           1287      2061
# Oct-2019          1942            590            862      1452
# Nov-2019          1902            948           2293      3241
# ...

# %%
NSW_df = NSW_df.T
NSW_df
# Out:
#                      Oct-2018 Nov-2018 Dec-2018 Jan-2019 Feb-2019 Mar-2019  \
# NSW_dwellings            2729     2600     1971     1980     2046     2201
# NSW_townhouses            669      834      519      642      749      788
# NSW_apartments           2179     1217     1461     1254     2296     1337
# NSW_other                2848     2051     1980     1896     3045     2125
# NSW_dwellings_$'000    925104   913709   699361   712699   726927   777751
# NSW_townhouses_$'000   186547   244155   153676   186472   228361   218526
# NSW_apartments_$'000   762982   428945   492138   447946   773759   455743
# NSW_other_$'000        949529   673100   645813   634418  1002120   674269
#
#                      Apr-2019 May-2019 Jun-2019 Jul-2019  ... Sep-2019  \
# NSW_dwellings            1746     2365     2000     2589  ...     1991
# NSW_townhouses            599      728      596      607  ...      774
# NSW_apartments           1801     1800     1477      932  ...     1287
# ...

# %% [markdown]
# ## NT

# %%
NT_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, NT.csv')
NT_df.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Total number of dwelling units ;  Northern Territory ;  New ;  Houses ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
#   Total number of dwelling units ;  Northern Territory ;  New ;  Semi-detached, row or terrace houses, townhouses - One storey ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
# ...

# %%
NT_df = NT_df.iloc[654:675, :]
NT_df = NT_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
NT_df
# Out:
#     Unnamed: 0  \
# 654   Oct-2009
# 655   Nov-2009
# 656   Dec-2009
# 657   Jan-2010
# 658   Feb-2010
# 659   Mar-2010
# 660   Apr-2010
# 661   May-2010
# 662   Jun-2010
# 663   Jul-2010
# 664   Aug-2010
# 665   Sep-2010
# 666   Oct-2010
# 667   Nov-2010
# 668   Dec-2010
# 669   Jan-2011
# 670   Feb-2011
# 671   Mar-2011
# 672   Apr-2011
# 673   May-2011
# 674   Jun-2011
#
#     Total number of dwelling units ;  Northern Territory ;  New ;  Houses ;  \
# 654                                                 56
# 655                                                 80
# 656                                                 94
# 657                                                 25
# 658                                                 40
# 659                                                 48
# 660                                                141
# 661                                                 47
# 662                                                 48
# ...

# %%
NT_df = NT_df.rename(columns={'Unnamed: 0': "",
    'Total number of dwelling units ;  Northern Territory ;  New ;  Houses ;': "NT_dwellings",
    'Total number of dwelling units ;  Northern Territory ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "NT_townhouses",
    'Total number of dwelling units ;  Northern Territory ;  New ;  Flats units or apartments - Total including those attached to a house ;': "NT_apartments",
    'Total number of dwelling units ;  Northern Territory ;  New ;  Total Other Residential ;': "NT_other",
    'Total value of building jobs ;  Northern Territory ;  New ;  Houses ;': "NT_dwellings_$'000",
    'Total value of building jobs ;  Northern Territory ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "NT_townhouses_$'000",
    'Total value of building jobs ;  Northern Territory ;  New ;  Flats units or apartments - Total including those attached to a house ;': "NT_apartments_$'000",
    'Total value of building jobs ;  Northern Territory ;  New ;  Total Other Residential ;': "NT_other_$'000"})
NT_df = NT_df.set_index('')
NT_df
# Out:
#          NT_dwellings NT_townhouses NT_apartments NT_other NT_dwellings_$'000  \
#
# Oct-2009           56             2            56       58              19594
# Nov-2009           80            17            27       44              26320
# Dec-2009           94            63            34       97              33332
# Jan-2010           25             8            16       24               8375
# Feb-2010           40             4             0        4              13560
# Mar-2010           48            14             0       14              15404
# Apr-2010          141            71            27       98              60189
# May-2010           47             8            30       38              15479
# Jun-2010           48            98            26      124              15120
# Jul-2010           45            13           198      211              15284
# Aug-2010           31            10           116      126              11287
# ...

# %%
NT_df = NT_df.T
NT_df
# Out:
#                     Oct-2009 Nov-2009 Dec-2009 Jan-2010 Feb-2010 Mar-2010  \
# NT_dwellings              56       80       94       25       40       48
# NT_townhouses              2       17       63        8        4       14
# NT_apartments             56       27       34       16        0        0
# NT_other                  58       44       97       24        4       14
# NT_dwellings_$'000     19594    26320    33332     8375    13560    15404
# NT_townhouses_$'000      886     5356    16166     2617     1182     4705
# NT_apartments_$'000    12050     6668     8003     4832        0        0
# NT_other_$'000         12936    12024    24169     7449     1182     4705
#
#                     Apr-2010 May-2010 Jun-2010 Jul-2010  ... Sep-2010  \
# NT_dwellings             141       47       48       45  ...      116
# NT_townhouses             71        8       98       13  ...       28
# NT_apartments             27       30       26      198  ...       57
# ...

# %% [markdown]
# ## QLD

# %%
QLD_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, QLD.csv')
QLD_df.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Total number of dwelling units ;  Queensland ;  New ;  Houses ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
#   Total number of dwelling units ;  Queensland ;  New ;  Semi-detached, row or terrace houses, townhouses - One storey ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
# ...

# %%
QLD_df = QLD_df.iloc[654:675, :]
QLD_df = QLD_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
QLD_df
# Out:
#     Unnamed: 0  \
# 654   Oct-2009
# 655   Nov-2009
# 656   Dec-2009
# 657   Jan-2010
# 658   Feb-2010
# 659   Mar-2010
# 660   Apr-2010
# 661   May-2010
# 662   Jun-2010
# 663   Jul-2010
# 664   Aug-2010
# 665   Sep-2010
# 666   Oct-2010
# 667   Nov-2010
# 668   Dec-2010
# 669   Jan-2011
# 670   Feb-2011
# 671   Mar-2011
# 672   Apr-2011
# 673   May-2011
# 674   Jun-2011
#
#     Total number of dwelling units ;  Queensland ;  New ;  Houses ;  \
# 654                                               2415
# 655                                               2338
# 656                                               1750
# 657                                               1570
# 658                                               1986
# 659                                               2414
# 660                                               1859
# 661                                               2074
# 662                                               1983
# ...

# %%
QLD_df = QLD_df.rename(columns={
    'Unnamed: 0': "",
    'Total number of dwelling units ;  Queensland ;  New ;  Houses ;': "QLD_dwellings",
    'Total number of dwelling units ;  Queensland ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "QLD_townhouses",
    'Total number of dwelling units ;  Queensland ;  New ;  Flats units or apartments - Total including those attached to a house ;': "QLD_apartments",
    'Total number of dwelling units ;  Queensland ;  New ;  Total Other Residential ;': "QLD_other",
    'Total value of building jobs ;  Queensland ;  New ;  Houses ;': "QLD_dwellings_$'000",
    'Total value of building jobs ;  Queensland ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "QLD_townhouses_$'000",
    'Total value of building jobs ;  Queensland ;  New ;  Flats units or apartments - Total including those attached to a house ;': "QLD_apartments_$'000",
    'Total value of building jobs ;  Queensland ;  New ;  Total Other Residential ;': "QLD_other_$'000"})
QLD_df = QLD_df.set_index('')
QLD_df
# Out:
#          QLD_dwellings QLD_townhouses QLD_apartments QLD_other  \
#
# Oct-2009          2415            378            175       553
# Nov-2009          2338            321            550       871
# Dec-2009          1750            331            656       987
# Jan-2010          1570            361            424       785
# Feb-2010          1986            383            590       973
# Mar-2010          2414            477            849      1326
# Apr-2010          1859            272           1016      1288
# May-2010          2074            428            700      1128
# Jun-2010          1983            521            798      1319
# Jul-2010          2061            335            279       614
# Aug-2010          2041            266            371       637
# Sep-2010          1929            537            350       887
# Oct-2010          1826            623            327       950
# Nov-2010          1828            450            396       846
# ...

# %%
QLD_df = QLD_df.T
QLD_df
# Out:
#                      Oct-2009 Nov-2009 Dec-2009 Jan-2010 Feb-2010 Mar-2010  \
# QLD_dwellings            2415     2338     1750     1570     1986     2414
# QLD_townhouses            378      321      331      361      383      477
# QLD_apartments            175      550      656      424      590      849
# QLD_other                 553      871      987      785      973     1326
# QLD_dwellings_$'000    639550   598383   440928   404351   518551   630961
# QLD_townhouses_$'000    56438    65910    60321    76229    81493    92278
# QLD_apartments_$'000    26486   133780   151010    77989   117576   180875
# QLD_other_$'000         82924   199690   211331   154218   199069   273153
#
#                      Apr-2010 May-2010 Jun-2010 Jul-2010  ... Sep-2010  \
# QLD_dwellings            1859     2074     1983     2061  ...     1929
# QLD_townhouses            272      428      521      335  ...      537
# QLD_apartments           1016      700      798      279  ...      350
# ...

# %% [markdown]
# ## SA

# %%
SA_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, SA.csv')
SA_df.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Total number of dwelling units ;  South Australia ;  New ;  Houses ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
#   Total number of dwelling units ;  South Australia ;  New ;  Semi-detached, row or terrace houses, townhouses - One storey ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
# ...

# %%
SA_df = SA_df.iloc[654:675, :]
SA_df = SA_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
SA_df
# Out:
#     Unnamed: 0  \
# 654   Oct-2009
# 655   Nov-2009
# 656   Dec-2009
# 657   Jan-2010
# 658   Feb-2010
# 659   Mar-2010
# 660   Apr-2010
# 661   May-2010
# 662   Jun-2010
# 663   Jul-2010
# 664   Aug-2010
# 665   Sep-2010
# 666   Oct-2010
# 667   Nov-2010
# 668   Dec-2010
# 669   Jan-2011
# 670   Feb-2011
# 671   Mar-2011
# 672   Apr-2011
# 673   May-2011
# 674   Jun-2011
#
#     Total number of dwelling units ;  South Australia ;  New ;  Houses ;  \
# 654                                                889
# 655                                                894
# 656                                                775
# 657                                                588
# 658                                                786
# 659                                               1127
# 660                                                825
# 661                                                896
# 662                                                845
# ...

# %%
SA_df = SA_df.rename(columns={'Unnamed: 0': "",
    'Total number of dwelling units ;  South Australia ;  New ;  Houses ;': "SA_dwellings",
    'Total number of dwelling units ;  South Australia ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "SA_townhouses",
    'Total number of dwelling units ;  South Australia ;  New ;  Flats units or apartments - Total including those attached to a house ;': "SA_apartments",
    'Total number of dwelling units ;  South Australia ;  New ;  Total Other Residential ;': "SA_other",
    'Total value of building jobs ;  South Australia ;  New ;  Houses ;': "SA_dwellings_$'000",
    'Total value of building jobs ;  South Australia ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "SA_townhouses_$'000",
    'Total value of building jobs ;  South Australia ;  New ;  Flats units or apartments - Total including those attached to a house ;': "SA_apartments_$'000",
    'Total value of building jobs ;  South Australia ;  New ;  Total Other Residential ;': "SA_other_$'000"})
SA_df = SA_df.set_index('')
SA_df
# Out:
#          SA_dwellings SA_townhouses SA_apartments SA_other SA_dwellings_$'000  \
#
# Oct-2009          889           108             6      114             166019
# Nov-2009          894           139            35      174             176144
# Dec-2009          775           158            49      207             143311
# Jan-2010          588           277            66      343             107745
# Feb-2010          786           105            27      132             146807
# Mar-2010         1127           151            26      177             220577
# Apr-2010          825           105            27      132             158496
# May-2010          896           407           128      535             165909
# Jun-2010          845           149            41      190             170389
# Jul-2010          932           151            70      221             185372
# Aug-2010          884           526            23      549             175783
# ...

# %%
SA_df = SA_df.T
SA_df
# Out:
#                     Oct-2009 Nov-2009 Dec-2009 Jan-2010 Feb-2010 Mar-2010  \
# SA_dwellings             889      894      775      588      786     1127
# SA_townhouses            108      139      158      277      105      151
# SA_apartments              6       35       49       66       27       26
# SA_other                 114      174      207      343      132      177
# SA_dwellings_$'000    166019   176144   143311   107745   146807   220577
# SA_townhouses_$'000    19279    19813    30432    44762    17649    23836
# SA_apartments_$'000     1300     7977     6900     7500     4160     5300
# SA_other_$'000         20579    27789    37332    52262    21809    29136
#
#                     Apr-2010 May-2010 Jun-2010 Jul-2010  ... Sep-2010  \
# SA_dwellings             825      896      845      932  ...      825
# SA_townhouses            105      407      149      151  ...      112
# SA_apartments             27      128       41       70  ...       82
# ...

# %% [markdown]
# ## TAS

# %%
TAS_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, TAS.csv')
TAS_df.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Total number of dwelling units ;  Tasmania ;  New ;  Houses ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
#   Total number of dwelling units ;  Tasmania ;  New ;  Semi-detached, row or terrace houses, townhouses - One storey ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
# ...

# %%
TAS_df = TAS_df.iloc[654:675, :]
TAS_df = TAS_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
TAS_df
# Out:
#     Unnamed: 0 Total number of dwelling units ;  Tasmania ;  New ;  Houses ;  \
# 654   Oct-2009                                                230
# 655   Nov-2009                                                235
# 656   Dec-2009                                                262
# 657   Jan-2010                                                182
# 658   Feb-2010                                                216
# 659   Mar-2010                                                193
# 660   Apr-2010                                                176
# 661   May-2010                                                193
# 662   Jun-2010                                                219
# 663   Jul-2010                                                195
# 664   Aug-2010                                                184
# 665   Sep-2010                                                182
# 666   Oct-2010                                                186
# ...

# %%
TAS_df = TAS_df.rename(columns={'Unnamed: 0': "",
    'Total number of dwelling units ;  Tasmania ;  New ;  Houses ;': "TAS_dwellings",
    'Total number of dwelling units ;  Tasmania ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "TAS_townhouses",
    'Total number of dwelling units ;  Tasmania ;  New ;  Flats units or apartments - Total including those attached to a house ;': "TAS_apartments",
    'Total number of dwelling units ;  Tasmania ;  New ;  Total Other Residential ;': "TAS_other",
    'Total value of building jobs ;  Tasmania ;  New ;  Houses ;': "TAS_dwellings_$'000",
    'Total value of building jobs ;  Tasmania ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "TAS_townhouses_$'000",
    'Total value of building jobs ;  Tasmania ;  New ;  Flats units or apartments - Total including those attached to a house ;': "TAS_apartments_$'000",
    'Total value of building jobs ;  Tasmania ;  New ;  Total Other Residential ;': "TAS_other_$'000"})                  
TAS_df = TAS_df.set_index('')
TAS_df
# Out:
#          TAS_dwellings TAS_townhouses TAS_apartments TAS_other  \
#
# Oct-2009           230             63             47       110
# Nov-2009           235             25              3        28
# Dec-2009           262             59             17        76
# Jan-2010           182             22              4        26
# Feb-2010           216             23             17        40
# Mar-2010           193             83              6        89
# Apr-2010           176             57              3        60
# May-2010           193             26              4        30
# Jun-2010           219             40             40        80
# Jul-2010           195             71             48       119
# Aug-2010           184             75              4        79
# Sep-2010           182             66             18        84
# Oct-2010           186             62             35        97
# Nov-2010           185             29             50        79
# ...

# %%
TAS_df = TAS_df.T
TAS_df
# Out:
#                      Oct-2009 Nov-2009 Dec-2009 Jan-2010 Feb-2010 Mar-2010  \
# TAS_dwellings             230      235      262      182      216      193
# TAS_townhouses             63       25       59       22       23       83
# TAS_apartments             47        3       17        4       17        6
# TAS_other                 110       28       76       26       40       89
# TAS_dwellings_$'000     49701    50074    56446    38753    47416    43618
# TAS_townhouses_$'000    10564     4045     8075     3260     3380    13585
# TAS_apartments_$'000    10010      360     2360      460     4534     1010
# TAS_other_$'000         20574     4405    10435     3720     7914    14595
#
#                      Apr-2010 May-2010 Jun-2010 Jul-2010  ... Sep-2010  \
# TAS_dwellings             176      193      219      195  ...      182
# TAS_townhouses             57       26       40       71  ...       66
# TAS_apartments              3        4       40       48  ...       18
# ...

# %% [markdown]
# ## VIC

# %%
VIC_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, VIC.csv')
VIC_df.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Total number of dwelling units ;  Victoria ;  New ;  Houses ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
#   Total number of dwelling units ;  Victoria ;  New ;  Semi-detached, row or terrace houses, townhouses - One storey ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
# ...

# %%
VIC_df = VIC_df.iloc[654:675, :]
VIC_df = VIC_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
VIC_df
# Out:
#     Unnamed: 0 Total number of dwelling units ;  Victoria ;  New ;  Houses ;  \
# 654   Oct-2009                                               3875
# 655   Nov-2009                                               3415
# 656   Dec-2009                                               2862
# 657   Jan-2010                                               2435
# 658   Feb-2010                                               3465
# 659   Mar-2010                                               3718
# 660   Apr-2010                                               3034
# 661   May-2010                                               3210
# 662   Jun-2010                                               3333
# 663   Jul-2010                                               3514
# 664   Aug-2010                                               3230
# 665   Sep-2010                                               3198
# 666   Oct-2010                                               3187
# ...

# %%
VIC_df = VIC_df.rename(columns={'Unnamed: 0': "",
    'Total number of dwelling units ;  Victoria ;  New ;  Houses ;': "VIC_dwellings",
    'Total number of dwelling units ;  Victoria ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "VIC_townhouses",
    'Total number of dwelling units ;  Victoria ;  New ;  Flats units or apartments - Total including those attached to a house ;': "VIC_apartments",
    'Total number of dwelling units ;  Victoria ;  New ;  Total Other Residential ;': "VIC_other",
    'Total value of building jobs ;  Victoria ;  New ;  Houses ;': "VIC_dwellings_$'000",
    'Total value of building jobs ;  Victoria ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "VIC_townhouses_$'000",
    'Total value of building jobs ;  Victoria ;  New ;  Flats units or apartments - Total including those attached to a house ;': "VIC_apartments_$'000",
    'Total value of building jobs ;  Victoria ;  New ;  Total Other Residential ;': "VIC_other_$'000"})
VIC_df = VIC_df.set_index('')
VIC_df
# Out:
#          VIC_dwellings VIC_townhouses VIC_apartments VIC_other  \
#
# Oct-2009          3875            521            429       950
# Nov-2009          3415            469            825      1294
# Dec-2009          2862            649           1145      1794
# Jan-2010          2435            379            716      1095
# Feb-2010          3465            622            569      1191
# Mar-2010          3718            954           1339      2293
# Apr-2010          3034            570           1303      1873
# May-2010          3210            737            813      1550
# Jun-2010          3333            672           1389      2061
# Jul-2010          3514            875           1586      2461
# Aug-2010          3230            745           2003      2748
# Sep-2010          3198            607           1718      2325
# Oct-2010          3187            682           1379      2061
# Nov-2010          3068            713           1218      1931
# ...

# %%
VIC_df = VIC_df.T
VIC_df
# Out:
#                      Oct-2009 Nov-2009 Dec-2009 Jan-2010 Feb-2010 Mar-2010  \
# VIC_dwellings            3875     3415     2862     2435     3465     3718
# VIC_townhouses            521      469      649      379      622      954
# VIC_apartments            429      825     1145      716      569     1339
# VIC_other                 950     1294     1794     1095     1191     2293
# VIC_dwellings_$'000    890532   816060   705151   581300   811906   916148
# VIC_townhouses_$'000    96162   102579   116459    79918   126029   184885
# VIC_apartments_$'000    76835   181154   237713   121639   127791   279793
# VIC_other_$'000        172997   283733   354172   201557   253820   464678
#
#                      Apr-2010 May-2010 Jun-2010 Jul-2010  ... Sep-2010  \
# VIC_dwellings            3034     3210     3333     3514  ...     3198
# VIC_townhouses            570      737      672      875  ...      607
# VIC_apartments           1303      813     1389     1586  ...     1718
# ...

# %% [markdown]
# ## WA

# %%
WA_df = pd.read_csv('/Users/sylviabroadbent/Dropbox/Sylvia/UWA_Data_Analytics_Bootcamp/HOMEWORK/7 Project 1/Data-Analytics-Project-1/Project 1 Raw Data/Residential construction -  new build, additions/Dwelling units approved, number and value, WA.csv')
WA_df.head()
# Out:
#          Unnamed: 0  \
# 0              Unit
# 1       Series Type
# 2         Data Type
# 3         Frequency
# 4  Collection Month
#
#   Total number of dwelling units ;  Western Australia ;  New ;  Houses ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
#   Total number of dwelling units ;  Western Australia ;  New ;  Semi-detached, row or terrace houses, townhouses - One storey ;  \
# 0                                             Number
# 1                                           Original
# 2                                               FLOW
# 3                                              Month
# 4                                                  1
#
# ...

# %%
WA_df = WA_df.iloc[654:675, :]
WA_df = WA_df.iloc[:, [0, 1, 4, 8, 9, 11, 14, 18, 19]]
WA_df
# Out:
#     Unnamed: 0  \
# 654   Oct-2009
# 655   Nov-2009
# 656   Dec-2009
# 657   Jan-2010
# 658   Feb-2010
# 659   Mar-2010
# 660   Apr-2010
# 661   May-2010
# 662   Jun-2010
# 663   Jul-2010
# 664   Aug-2010
# 665   Sep-2010
# 666   Oct-2010
# 667   Nov-2010
# 668   Dec-2010
# 669   Jan-2011
# 670   Feb-2011
# 671   Mar-2011
# 672   Apr-2011
# 673   May-2011
# 674   Jun-2011
#
#     Total number of dwelling units ;  Western Australia ;  New ;  Houses ;  \
# 654                                               1878
# 655                                               1824
# 656                                               1625
# 657                                               1387
# 658                                               1815
# 659                                               1679
# 660                                               1473
# 661                                               1736
# 662                                               1784
# ...

# %%
WA_df = WA_df.rename(columns={'Unnamed: 0': "",
    'Total number of dwelling units ;  Western Australia ;  New ;  Houses ;': "WA_dwellings",
    'Total number of dwelling units ;  Western Australia ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "WA_townhouses",
    'Total number of dwelling units ;  Western Australia ;  New ;  Flats units or apartments - Total including those attached to a house ;': "WA_apartments",
    'Total number of dwelling units ;  Western Australia ;  New ;  Total Other Residential ;': "WA_other",
    'Total value of building jobs ;  Western Australia ;  New ;  Houses ;': "WA_dwellings_$'000",
    'Total value of building jobs ;  Western Australia ;  New ;  Semi-detached, row or terrace houses, townhouses - Total ;': "WA_townhouses_$'000",
    'Total value of building jobs ;  Western Australia ;  New ;  Flats units or apartments - Total including those attached to a house ;': "WA_apartments_$'000",
    'Total value of building jobs ;  Western Australia ;  New ;  Total Other Residential ;': "WA_other_$'000"})
WA_df = WA_df.set_index('')
WA_df
# Out:
#          WA_dwellings WA_townhouses WA_apartments WA_other WA_dwellings_$'000  \
#
# Oct-2009         1878           318            61      379             476592
# Nov-2009         1824           281            25      306             439221
# Dec-2009         1625           198           147      345             425620
# Jan-2010         1387           395           226      621             355589
# Feb-2010         1815           291           335      626             464227
# Mar-2010         1679           646           248      894             456973
# Apr-2010         1473           261           207      468             392310
# May-2010         1736           217           135      352             463877
# Jun-2010         1784           190            82      272             463159
# Jul-2010         1418           357            35      392             381921
# Aug-2010         1695           119            60      179             468258
# ...

# %%
WA_df = WA_df.T
WA_df
# Out:
#                     Oct-2009 Nov-2009 Dec-2009 Jan-2010 Feb-2010 Mar-2010  \
# WA_dwellings            1878     1824     1625     1387     1815     1679
# WA_townhouses            318      281      198      395      291      646
# WA_apartments             61       25      147      226      335      248
# WA_other                 379      306      345      621      626      894
# WA_dwellings_$'000    476592   439221   425620   355589   464227   456973
# WA_townhouses_$'000    62276    51740    40306    85524    59881   122276
# WA_apartments_$'000    16714     5737    37504    49495    67153   128804
# WA_other_$'000         78990    57477    77811   135019   127034   251080
#
#                     Apr-2010 May-2010 Jun-2010 Jul-2010  ... Sep-2010  \
# WA_dwellings            1473     1736     1784     1418  ...     1538
# WA_townhouses            261      217      190      357  ...      231
# WA_apartments            207      135       82       35  ...       67
# ...

# %% [markdown]
# # Combined DataFrame

# %%
AU_df = pd.concat([ACT_df, NSW_df, NT_df, QLD_df, SA_df, TAS_df, VIC_df, WA_df])
AU_df
# Out:
#                     Oct-2018 Nov-2018 Dec-2018 Jan-2019 Feb-2019 Mar-2019  \
# ACT_dwellings            133      123       75       75      119      106
# ACT_townhouses            80       90       98      133      140       25
# ACT_apartments           439      349       85       94        0      430
# ACT_other                519      439      183      227      140      455
# ACT_dwellings_$'000    51156    45194    26703    33687    44973    41343
# ...                      ...      ...      ...      ...      ...      ...
# WA_other                 NaN      NaN      NaN      NaN      NaN      NaN
# WA_dwellings_$'000       NaN      NaN      NaN      NaN      NaN      NaN
# WA_townhouses_$'000      NaN      NaN      NaN      NaN      NaN      NaN
# WA_apartments_$'000      NaN      NaN      NaN      NaN      NaN      NaN
# WA_other_$'000           NaN      NaN      NaN      NaN      NaN      NaN
#
#                     Apr-2019 May-2019 Jun-2019 Jul-2019  ... Sep-2010  \
# ...

# %%
AU_df.to_csv('Res_Construction_Data_all_States.csv')

# %%
WA_df.to_csv('Res_Construction_Data_WA.csv')
